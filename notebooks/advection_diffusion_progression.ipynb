# %%
import os
import sys
import numpy as np
import pandas as pd
from scipy import misc
import matplotlib.pyplot as plt
from scipy import sparse
from scipy.sparse import csgraph
from scipy import linalg
from pysheds.grid import Grid
from scipy import ndimage
from matplotlib import colors
import seaborn as sns

# %matplotlib inline

# %%
sns.set_palette('husl', 2)

# %%
grid = Grid.from_raster('../../pysheds/data/n30w100_dir',
                 data_name='dir', input_type='ascii')

# %%
grid.read_raster('../../pysheds/data/n30w100_con',
                 data_name='dem', input_type='ascii')

# %%
dirmap = (64,  128,  1,   2,    4,   8,    16,  32)

# Specify pour point
x, y = -97.294167, 32.73750

# Delineate the catchment
grid.catchment(data='dir', x=x, y=y, dirmap=dirmap, out_name='catch',
               recursionlimit=15000, xytype='label')
# Clip the bounding box to the catchment
grid.clip_to('catch', precision=5)

grid.accumulation(data='catch', dirmap=dirmap, pad_inplace=False, out_name='acc')

# %%
profiles, connections = grid.extract_profiles('catch', grid.acc > 25)

# %%
geom = grid.extract_river_network('catch', grid.acc > 25)

# %%
dx = 60. * (np.asarray([profile.size for profile in profiles]) + 1)
n = max(max(connections.keys()), max(connections.values())) + 1
s = np.ones(n)
I = np.eye(n)
u = np.ones(n)
D = (u * dx / 10).mean()*np.ones(n)
dt = 1
I[0, 0] = 0

# %%
(u * dx / D).mean()
# Out:
# 10.0

# %%
#dx = np.ones(n)
#dx[43] = 15.
#dx[41] = 15.

# %%
U = np.zeros((n, n))
W = np.zeros((n, n))

for i, j in connections.items():
    # Confirmed as i
    U[j, i] = u[i] * dt / dx[i]
    W[i, j] = u[i] * dt / dx[i]

# %%
V = np.diag(W @ s)

# %%
X = np.zeros((n, n))

for i, j in connections.items():
    X[i, j] = 2 / (dx[i] + dx[j])
    X[j, i] = 2 / (dx[i] + dx[j])
    
Y = np.diag(X @ s)

# %%
Z = np.diag(D * dt / dx)

# %%
S = (U - V) - Z @ (Y - X) + I

# %%
np.imag(np.linalg.eig(S)[0]).max(), np.imag(np.linalg.eig(S)[0]).min(), np.real(np.linalg.eig(S)[0]).max(), np.real(np.linalg.eig(S)[0]).min()
# Out:
# (0.0, 0.0, 0.9997196165216538, -0.0027755206889173286)

# %%
sr = s# + np.random.randn(len(s))

# %%
from matplotlib.animation import FuncAnimation, ArtistAnimation
from IPython.display import HTML

# %%
import matplotlib
import matplotlib.cm as cm
from matplotlib.collections import LineCollection

mag = np.linalg.matrix_power(S, 10) @ s

norm = matplotlib.colors.Normalize(vmin=0, vmax=mag.max())
mapper = cm.ScalarMappable(norm=norm, cmap=cm.plasma)
colors = mapper.to_rgba(mag)

# %%
p = pd.Series(connections).values

# %%
fig, ax = plt.subplots(1, 3, figsize=(12,10))

segs = [np.asarray(branch['geometry']['coordinates']) for branch in geom['features']]

for i in range(3):
    ax[i].set_facecolor('w')
    ax[i].xaxis.set_ticklabels([])
    ax[i].yaxis.set_ticklabels([])

ax[0].imshow(np.where(grid.view('catch'), 1, np.nan), zorder=1, cmap='Greys',
             vmin=0, vmax=6, extent=grid.extent, alpha=0.5)
mag = np.linalg.matrix_power(S, 1000) @ s
lmag = np.log10(mag + 1)
norm = matplotlib.colors.Normalize(vmin=0, vmax=20)
mapper = cm.ScalarMappable(norm=norm, cmap=cm.winter)
colors = mapper.to_rgba(mag)
line_segments = LineCollection(segs, colors=colors, linewidths=1.75*lmag)
im = ax[0].add_collection(line_segments)
ax[0].autoscale()
ax[0].annotate('$t=1000 \ s$', (0.10, 0.75), xycoords='axes fraction')

ax[1].imshow(np.where(grid.view('catch'), 1, np.nan), zorder=1, cmap='Greys',
             vmin=0, vmax=6, extent=grid.extent, alpha=0.5)
mag = np.linalg.matrix_power(S, 8000) @ s
lmag = np.log10(mag + 1)
norm = matplotlib.colors.Normalize(vmin=0, vmax=20)
mapper = cm.ScalarMappable(norm=norm, cmap=cm.winter)
colors = mapper.to_rgba(mag)
line_segments = LineCollection(segs, colors=colors, linewidths=1.75*lmag)
im = ax[1].add_collection(line_segments)
ax[1].autoscale()
ax[1].annotate('$t=3000 \ s$', (0.10, 0.75), xycoords='axes fraction')

ax[2].imshow(np.where(grid.view('catch'), 1, np.nan), zorder=1, cmap='Greys',
             vmin=0, vmax=6, extent=grid.extent, alpha=0.5)
mag = np.linalg.matrix_power(S, 24000) @ s
lmag = np.log10(mag + 1)
norm = matplotlib.colors.Normalize(vmin=0, vmax=20)
mapper = cm.ScalarMappable(norm=norm, cmap=cm.winter)
colors = mapper.to_rgba(mag)
line_segments = LineCollection(segs, colors=colors, linewidths=1.75*lmag)
im = ax[2].add_collection(line_segments)
ax[2].autoscale()
ax[2].annotate('$t=12000 \ s$', (0.10, 0.75), xycoords='axes fraction')

plt.tight_layout()
#plt.savefig('contaminant_progression_3.png', bbox_inches='tight')

# %%
fig, ax = plt.subplots(1, 3, figsize=(12,10))

segs = [np.asarray(branch['geometry']['coordinates']) for branch in geom['features']]

for i in range(3):
    ax[i].set_facecolor('w')
    ax[i].xaxis.set_ticklabels([])
    ax[i].yaxis.set_ticklabels([])

ax[0].imshow(np.where(grid.view('catch'), 1, np.nan), zorder=1, cmap='Greys',
             vmin=0, vmax=6, extent=grid.extent, alpha=0.5)
mag = np.linalg.matrix_power(S, 1200) @ s
lmag = np.log10(mag + 1)
norm = matplotlib.colors.Normalize(vmin=0, vmax=20)
mapper = cm.ScalarMappable(norm=norm, cmap=cm.winter)
colors = mapper.to_rgba(mag)
line_segments = LineCollection(segs, color='0.5', alpha=0.35, linewidths=0.5)
im = ax[0].add_collection(line_segments)
line_segments = LineCollection(segs, colors=colors, linewidths=1.75*lmag)
im = ax[0].add_collection(line_segments)
ax[0].autoscale()
ax[0].annotate('$t=20 \ min$', (0.10, 0.75), xycoords='axes fraction')

ax[1].imshow(np.where(grid.view('catch'), 1, np.nan), zorder=1, cmap='Greys',
             vmin=0, vmax=6, extent=grid.extent, alpha=0.5)
mag = np.linalg.matrix_power(S, 7200) @ s
lmag = np.log10(mag + 1)
norm = matplotlib.colors.Normalize(vmin=0, vmax=20)
mapper = cm.ScalarMappable(norm=norm, cmap=cm.winter)
colors = mapper.to_rgba(mag)
line_segments = LineCollection(segs, color='0.5', alpha=0.35, linewidths=0.5)
im = ax[1].add_collection(line_segments)
line_segments = LineCollection(segs, colors=colors, linewidths=1.75*lmag)
im = ax[1].add_collection(line_segments)
ax[1].autoscale()
ax[1].annotate('$t=120 \ min$', (0.10, 0.75), xycoords='axes fraction')

ax[2].imshow(np.where(grid.view('catch'), 1, np.nan), zorder=1, cmap='Greys',
             vmin=0, vmax=6, extent=grid.extent, alpha=0.5)
mag = np.linalg.matrix_power(S, 24000) @ s
lmag = np.log10(mag + 1)
norm = matplotlib.colors.Normalize(vmin=0, vmax=20)
mapper = cm.ScalarMappable(norm=norm, cmap=cm.winter)
colors = mapper.to_rgba(mag)
line_segments = LineCollection(segs, color='0.5', alpha=0.35, linewidths=0.5)
im = ax[2].add_collection(line_segments)
line_segments = LineCollection(segs, colors=colors, linewidths=1.75*lmag)
im = ax[2].add_collection(line_segments)
ax[2].autoscale()
ax[2].annotate('$t=400 \ min$', (0.10, 0.75), xycoords='axes fraction')

plt.tight_layout()
#plt.savefig('contaminant_progression_3.png', bbox_inches='tight')

# %%
import matplotlib.gridspec as gridspec

# %%
fig = plt.figure(figsize=(14,4))
spec = gridspec.GridSpec(ncols=4, nrows=1, figure=fig, width_ratios=[1, 1, 1, 0.05])

ax = []
ax.append(fig.add_subplot(spec[0]))
ax.append(fig.add_subplot(spec[1]))
ax.append(fig.add_subplot(spec[2]))
ax.append(fig.add_subplot(spec[3]))

segs = [np.asarray(branch['geometry']['coordinates']) for branch in geom['features']]

for i in range(3):
    ax[i].set_facecolor('w')
    ax[i].xaxis.set_ticklabels([])
    ax[i].yaxis.set_ticklabels([])

ax[0].imshow(np.where(grid.view('catch'), 1, np.nan), zorder=1, cmap='Greys',
             vmin=0, vmax=6, extent=grid.extent, alpha=0.5)
mag = np.linalg.matrix_power(S, 1200) @ s
lmag = np.log10(mag + 1)
norm = matplotlib.colors.Normalize(vmin=0, vmax=20)
mapper = cm.ScalarMappable(norm=norm, cmap=cm.winter)
colors = mapper.to_rgba(mag)
line_segments = LineCollection(segs, color='0.5', alpha=0.35, linewidths=0.5)
im = ax[0].add_collection(line_segments)
line_segments = LineCollection(segs, colors=colors, linewidths=1.75*lmag)
im = ax[0].add_collection(line_segments)
ax[0].autoscale()
ax[0].annotate('$t=20 \ min$', (0.10, 0.75), xycoords='axes fraction')

ax[1].imshow(np.where(grid.view('catch'), 1, np.nan), zorder=1, cmap='Greys',
             vmin=0, vmax=6, extent=grid.extent, alpha=0.5)
mag = np.linalg.matrix_power(S, 7200) @ s
lmag = np.log10(mag + 1)
norm = matplotlib.colors.Normalize(vmin=0, vmax=20)
mapper = cm.ScalarMappable(norm=norm, cmap=cm.winter)
colors = mapper.to_rgba(mag)
line_segments = LineCollection(segs, color='0.5', alpha=0.35, linewidths=0.5)
im = ax[1].add_collection(line_segments)
line_segments = LineCollection(segs, colors=colors, linewidths=1.75*lmag)
im = ax[1].add_collection(line_segments)
ax[1].autoscale()
ax[1].annotate('$t=120 \ min$', (0.10, 0.75), xycoords='axes fraction')

ax[2].imshow(np.where(grid.view('catch'), 1, np.nan), zorder=1, cmap='Greys',
             vmin=0, vmax=6, extent=grid.extent, alpha=0.5)
mag = np.linalg.matrix_power(S, 24000) @ s
lmag = np.log10(mag + 1)
norm = matplotlib.colors.Normalize(vmin=0, vmax=20)
mapper = cm.ScalarMappable(norm=norm, cmap=cm.winter)
colors = mapper.to_rgba(mag)
line_segments = LineCollection(segs, color='0.5', alpha=0.35, linewidths=0.5)
im = ax[2].add_collection(line_segments)
line_segments = LineCollection(segs, colors=colors, linewidths=1.75*lmag)
im = ax[2].add_collection(line_segments)
ax[2].autoscale()
ax[2].annotate('$t=400 \ min$', (0.10, 0.75), xycoords='axes fraction')

cb1 = matplotlib.colorbar.ColorbarBase(ax[3], cmap='winter',
                                norm=norm,
                                orientation='vertical',
                                label='Quantity per unit length $[g/m]$',
                                extend='max')
ax[3].yaxis.set_label_position('right')

plt.tight_layout()
#plt.savefig('contaminant_progression_3.png', bbox_inches='tight')

# %%
fig = plt.figure(figsize=(14,4))
spec = gridspec.GridSpec(ncols=5, nrows=1, figure=fig, width_ratios=[1, 1, 1, 0.1, 0.05])

ax = []
ax.append(fig.add_subplot(spec[0]))
ax.append(fig.add_subplot(spec[1]))
ax.append(fig.add_subplot(spec[2]))
ax.append(fig.add_subplot(spec[3]))
ax.append(fig.add_subplot(spec[4]))

segs = [np.asarray(branch['geometry']['coordinates']) for branch in geom['features']]

for i in range(4):
    ax[i].set_facecolor('w')
    ax[i].xaxis.set_ticklabels([])
    ax[i].yaxis.set_ticklabels([])

ax[0].imshow(np.where(grid.view('catch'), 1, np.nan), zorder=1, cmap='Greys',
             vmin=0, vmax=6, extent=grid.extent, alpha=0.5)
mag = np.linalg.matrix_power(S, 1200) @ s
lmag = np.log10(mag + 1)
norm = matplotlib.colors.Normalize(vmin=0, vmax=20)
mapper = cm.ScalarMappable(norm=norm, cmap=cm.winter)
colors = mapper.to_rgba(mag)
line_segments = LineCollection(segs, color='0.5', alpha=0.35, linewidths=0.5)
im = ax[0].add_collection(line_segments)
line_segments = LineCollection(segs, colors=colors, linewidths=1.75*lmag)
im = ax[0].add_collection(line_segments)
ax[0].autoscale()
ax[0].annotate('$t=20 \ min.$', (0.10, 0.75), xycoords='axes fraction')

ax[1].imshow(np.where(grid.view('catch'), 1, np.nan), zorder=1, cmap='Greys',
             vmin=0, vmax=6, extent=grid.extent, alpha=0.5)
mag = np.linalg.matrix_power(S, 7200) @ s
lmag = np.log10(mag + 1)
norm = matplotlib.colors.Normalize(vmin=0, vmax=20)
mapper = cm.ScalarMappable(norm=norm, cmap=cm.winter)
colors = mapper.to_rgba(mag)
line_segments = LineCollection(segs, color='0.5', alpha=0.35, linewidths=0.5)
im = ax[1].add_collection(line_segments)
line_segments = LineCollection(segs, colors=colors, linewidths=1.75*lmag)
im = ax[1].add_collection(line_segments)
ax[1].autoscale()
ax[1].annotate('$t=120 \ min.$', (0.10, 0.75), xycoords='axes fraction')

ax[2].imshow(np.where(grid.view('catch'), 1, np.nan), zorder=1, cmap='Greys',
             vmin=0, vmax=6, extent=grid.extent, alpha=0.5)
mag = np.linalg.matrix_power(S, 24000) @ s
lmag = np.log10(mag + 1)
norm = matplotlib.colors.Normalize(vmin=0, vmax=20)
mapper = cm.ScalarMappable(norm=norm, cmap=cm.winter)
colors = mapper.to_rgba(mag)
line_segments = LineCollection(segs, color='0.5', alpha=0.35, linewidths=0.5)
im = ax[2].add_collection(line_segments)
line_segments = LineCollection(segs, colors=colors, linewidths=1.75*lmag)
im = ax[2].add_collection(line_segments)
ax[2].autoscale()
ax[2].annotate('$t=400 \ min.$', (0.10, 0.75), xycoords='axes fraction')

cb1 = matplotlib.colorbar.ColorbarBase(ax[4], cmap='winter',
                                norm=norm,
                                orientation='vertical',
                                label='Quantity per unit length $[g / m]$',
                                extend='max')
ax[3].yaxis.set_label_position('right')

plt.tight_layout()
plt.savefig('contaminant_progression_bar.png', bbox_inches='tight', dpi=200)

# %%
1200 / 60, 7200 / 60, 24000 / 60
# Out:
# (20.0, 120.0, 400.0)

# %%
fig, ax = plt.subplots(1, 4, figsize=(12,10))

segs = [np.asarray(branch['geometry']['coordinates']) for branch in geom['features']]

for i in range(4):
    ax[i].set_facecolor('w')
    ax[i].xaxis.set_ticklabels([])
    ax[i].yaxis.set_ticklabels([])

ax[0].imshow(np.where(grid.view('catch'), 1, np.nan), zorder=1, cmap='Greys',
             vmin=0, vmax=6, extent=grid.extent, alpha=0.5)
mag = np.linalg.matrix_power(S, 10) @ s
lmag = np.log10(mag + 1)
norm = matplotlib.colors.Normalize(vmin=0, vmax=10)
mapper = cm.ScalarMappable(norm=norm, cmap=cm.winter)
colors = mapper.to_rgba(mag)
line_segments = LineCollection(segs, colors=colors, linewidths=1.5*lmag)
im = ax[0].add_collection(line_segments)
ax[0].autoscale()
ax[0].annotate('$t=100 \ s$', (0.10, 0.75), xycoords='axes fraction')

ax[1].imshow(np.where(grid.view('catch'), 1, np.nan), zorder=1, cmap='Greys',
             vmin=0, vmax=6, extent=grid.extent, alpha=0.5)
mag = np.linalg.matrix_power(S, 2000) @ s
lmag = np.log10(mag + 1)
norm = matplotlib.colors.Normalize(vmin=0, vmax=10)
mapper = cm.ScalarMappable(norm=norm, cmap=cm.winter)
colors = mapper.to_rgba(mag)
line_segments = LineCollection(segs, colors=colors, linewidths=1.5*lmag)
im = ax[1].add_collection(line_segments)
ax[1].autoscale()
ax[1].annotate('$t=500 \ s$', (0.10, 0.75), xycoords='axes fraction')

ax[2].imshow(np.where(grid.view('catch'), 1, np.nan), zorder=1, cmap='Greys',
             vmin=0, vmax=6, extent=grid.extent, alpha=0.5)
mag = np.linalg.matrix_power(S, 8000) @ s
lmag = np.log10(mag + 1)
norm = matplotlib.colors.Normalize(vmin=0, vmax=10)
mapper = cm.ScalarMappable(norm=norm, cmap=cm.winter)
colors = mapper.to_rgba(mag)
line_segments = LineCollection(segs, colors=colors, linewidths=1.5*lmag)
im = ax[2].add_collection(line_segments)
ax[2].autoscale()
ax[2].annotate('$t=1000 \ s$', (0.10, 0.75), xycoords='axes fraction')

ax[3].imshow(np.where(grid.view('catch'), 1, np.nan), zorder=1, cmap='Greys',
             vmin=0, vmax=6, extent=grid.extent, alpha=0.5)
mag = np.linalg.matrix_power(S, 28000) @ s
lmag = np.log10(mag + 1)
norm = matplotlib.colors.Normalize(vmin=0, vmax=10)
mapper = cm.ScalarMappable(norm=norm, cmap=cm.winter)
colors = mapper.to_rgba(mag)
line_segments = LineCollection(segs, colors=colors, linewidths=1.5*lmag)
im = ax[3].add_collection(line_segments)
ax[3].autoscale()
ax[3].annotate('$t=2700 \ s$', (0.10, 0.75), xycoords='axes fraction')

plt.tight_layout()
plt.savefig('contaminant_progression.png', bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(8,8))

ims = []

segs = [np.asarray(branch['geometry']['coordinates']) for branch in geom['features']]
line_segments = LineCollection(segs)
_ = ax.add_collection(line_segments)
ax.autoscale()
_.remove()
ax.set_facecolor('w')
ax.xaxis.set_ticklabels([])
ax.yaxis.set_ticklabels([])

ax.imshow(np.where(grid.view('catch'), 1, np.nan), zorder=1, cmap='Greys', vmin=0, vmax=6, extent=grid.extent, alpha=0.5)

for i in range(0, 300, 10):
    mag = np.linalg.matrix_power(S, i) @ (sr)
#    mag = (mag + mag[p]) / 2
    lmag = np.log10(mag + 1)
    norm = matplotlib.colors.Normalize(vmin=0, vmax=10)
    mapper = cm.ScalarMappable(norm=norm, cmap=cm.winter)
    colors = mapper.to_rgba(mag)
    line_segments = LineCollection(segs, colors=colors, linewidths=4*lmag)
    im = ax.add_collection(line_segments)
    ims.append([im])

# %%
im_ani = ArtistAnimation(fig, ims, interval=120, repeat_delay=3000,
                         blit=True)

# %%
#HTML(im_ani.to_html5_video())
